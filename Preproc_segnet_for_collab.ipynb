# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Layer

physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

class MaxPoolingWithArgmax2D(Layer):

    def __init__(
            self,
            pool_size=(2, 2),
            strides=(2, 2),
            padding='same',
            **kwargs):
        super(MaxPoolingWithArgmax2D, self).__init__(**kwargs)
        self.padding = padding
        self.pool_size = pool_size
        self.strides = strides

    def call(self, inputs, **kwargs):
        padding = self.padding
        pool_size = self.pool_size
        strides = self.strides
        ksize = [1, *pool_size, 1]
        padding = padding.upper()
        strides = [1, *strides, 1]
        output, argmax = tf.nn.max_pool_with_argmax(
            inputs,
            ksize=ksize,
            strides=strides,
            padding=padding)

        argmax = K.cast(argmax, K.floatx())
        return [output, argmax]

    def compute_output_shape(self, input_shape):
        ratio = (1, 2, 2, 1)
        output_shape = [
            dim // ratio[idx]
            if dim is not None else None
            for idx, dim in enumerate(input_shape)]
        output_shape = tuple(output_shape)
        return [output_shape, output_shape]

    def compute_mask(self, inputs, mask=None):
        return 2 * [None]


class MaxUnpooling2D(Layer):
    def __init__(self, pool_size=(2, 2), **kwargs):
        super(MaxUnpooling2D, self).__init__(**kwargs)
        self.size = pool_size

    def call(self, inputs, output_shape=None):
        updates, mask = inputs[0], inputs[1]
        mask = K.cast(mask, 'int32')
        input_shape = tf.shape(updates, out_type='int32')

        if output_shape is None:
            output_shape = (
                input_shape[0],
                input_shape[1] * self.size[0],
                input_shape[2] * self.size[1],
                input_shape[3])

        ret = tf.scatter_nd(K.expand_dims(K.flatten(mask)),
                            K.flatten(updates),
                            [K.prod(output_shape)])

        input_shape = updates.shape
        out_shape = [-1,
                     input_shape[1] * self.size[0],
                     input_shape[2] * self.size[1],
                     input_shape[3]]
        return K.reshape(ret, out_shape)

    def compute_output_shape(self, input_shape):
        mask_shape = input_shape[1]
        return (
            mask_shape[0],
            mask_shape[1] * self.size[0],
            mask_shape[2] * self.size[1],
            mask_shape[3]
        )

def segnet(input_shape, n_labels, num_filters=32, output_mode="softmax"):
    inputs = Input(shape=input_shape)

    conv_1 = Convolution2D(num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(inputs)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Activation("relu")(conv_1)

    pool_1, mask_1 = MaxPoolingWithArgmax2D(pool_size=(2, 2))(conv_1)

    conv_2 = Convolution2D(2 * num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(pool_1)
    conv_2 = BatchNormalization()(conv_2)
    conv_2 = Activation("relu")(conv_2)

    pool_2, mask_2 = MaxPoolingWithArgmax2D(pool_size=(2, 2))(conv_2)

    conv_3 = Convolution2D(2 * num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(pool_2)
    conv_3 = BatchNormalization()(conv_3)
    conv_3 = Activation("relu")(conv_3)

    pool_3, mask_3 = MaxPoolingWithArgmax2D(pool_size=(2, 2))(conv_3)

    conv_4 = Convolution2D(4 * num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(pool_3)
    conv_4 = BatchNormalization()(conv_4)
    conv_4 = Activation("relu")(conv_4)

    pool_4, mask_4 = MaxPoolingWithArgmax2D(pool_size=(2, 2))(conv_4)

    unpool_1 = MaxUnpooling2D(pool_size=(2, 2))([pool_4, mask_4])

    conv_5 = Convolution2D(2 * num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(unpool_1)
    conv_5 = BatchNormalization()(conv_5)
    conv_5 = Activation("relu")(conv_5)

    unpool_2 = MaxUnpooling2D(pool_size=(2, 2))([conv_5, mask_3])

    conv_6 = Convolution2D(2 * num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(unpool_2)
    conv_6 = BatchNormalization()(conv_6)
    conv_6 = Activation("relu")(conv_6)

    unpool_3 = MaxUnpooling2D(pool_size=(2, 2))([conv_6, mask_2])

    conv_7 = Convolution2D(num_filters, (3, 3), padding="same", kernel_initializer='he_normal')(unpool_3)
    conv_7 = BatchNormalization()(conv_7)
    conv_7 = Activation("relu")(conv_7)

    unpool_4 = MaxUnpooling2D(pool_size=(2, 2))([conv_7, mask_1])

    conv_8 = Convolution2D(n_labels, (1, 1), padding="same", kernel_initializer='he_normal')(unpool_4)
    conv_8 = BatchNormalization()(conv_8)
    outputs = Activation(output_mode)(conv_8)

    segnet = Model(inputs=inputs, outputs=outputs)
    return segnet

# %%
#The imports we will all need
from matplotlib import pyplot as plt 
from PIL import Image, ImageOps
import os
import numpy as np
import cv2
from sklearn.metrics import roc_curve, auc, f1_score
import glob


#You may have to remove this import and all the @njit wrappers at the top of each function
#I don't think numba works with collab is why
#If it does, keep it. The preproccessing code will run faster if the wrappers are present
#The preprocessing code will take a bit to run without it... I brute forced everything :/
from numba import njit

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#The original size of the images, leave as is
OG_SIZE = (1000, 1000)

#The size of image that will be put into the NN
NEW_SIZE = (512, 512)

#Resizing flag. If true resizing will be used to make input of size NEW_SIZE
#If false, padding is added on the left and bottom sides of image to make input of size NEW_SIZE
#if using padding, you can only increase dims of OG_SIZE.
RESIZE = True

#The interpolation method for when you want to resize (.tiff and np.arrays will only work with INTER_NEAREST)
interp = cv2.INTER_NEAREST

#How many times to split up the image for the NN
#Only need to use this if having memory troubles
#Will turn 1 (1024,1024) image into 4 (512,512) images for DIV = 2 (or 16 (256,256) for DIV=4 and so on)
DIV = 1


#Scales all input images between 0 and 1
def Scale(arr):
    arr = (arr-np.min(arr))/(np.max(arr)-np.min(arr))
    return arr


#Reserve the space for all inputs and outputs
train_imgs = np.zeros((26,NEW_SIZE[0],NEW_SIZE[1]))
valid_imgs = np.zeros((6,NEW_SIZE[0],NEW_SIZE[1]))
test_imgs = np.zeros((6,NEW_SIZE[0],NEW_SIZE[1]))

train_masks = np.zeros((26,NEW_SIZE[0],NEW_SIZE[1]))
valid_masks = np.zeros((6,NEW_SIZE[0],NEW_SIZE[1]))
test_masks = np.zeros((6,NEW_SIZE[0],NEW_SIZE[1]))

tr = 0
va = 0
te = 0

path = '/content/drive/MyDrive/Images/'

#Goes into Images folder in same folder as this .ipynb and extracts neccesary data
#Make sure you have this folder downloaded the same way as the GitHub 'Images' folder I posted
for folder in os.listdir(path):
    for image in sorted(glob.glob(path + folder + '/*.tif')):
        identifier = image[len(image)-8:len(image)-4]
            
        img = Image.open(image)
            
        if folder == 'data_trainset':
            if identifier == 'mask':
                if RESIZE:
                    train_masks[tr,0:NEW_SIZE[0],0:NEW_SIZE[1]] = cv2.resize(np.asarray(img)/255, NEW_SIZE, interpolation = interp)
                    tr += 1
                else:
                    train_masks[tr,0:OG_SIZE[0],0:OG_SIZE[1]] = np.asarray(img)/255
                    tr += 1
            else:
                if RESIZE:
                    train_imgs[tr,0:NEW_SIZE[0],0:NEW_SIZE[1]] = cv2.resize(Scale(np.asarray(img)), NEW_SIZE, interpolation = interp)
                else:
                    train_imgs[tr,0:OG_SIZE[0],0:OG_SIZE[1]] = Scale(np.asarray(img))
                    
                    
        elif folder == 'data_validset':
            if identifier == 'mask':
                if RESIZE:
                    valid_masks[va,0:NEW_SIZE[0],0:NEW_SIZE[1]] = cv2.resize(np.asarray(img)/255, NEW_SIZE, interpolation = interp)
                    va += 1
                else:
                    valid_masks[va,0:OG_SIZE[0],0:OG_SIZE[1]] = np.asarray(img)/255
                    va += 1
            else:
                if RESIZE:
                    valid_imgs[va,0:NEW_SIZE[0],0:NEW_SIZE[1]] = cv2.resize(Scale(np.asarray(img)), NEW_SIZE, interpolation = interp)
                else:
                    valid_imgs[va,0:OG_SIZE[0],0:OG_SIZE[1]] = Scale(np.asarray(img))
                
                
        elif folder == 'data_testset':
            if identifier == 'mask':
                if RESIZE:
                    test_masks[te,0:NEW_SIZE[0],0:NEW_SIZE[1]] = cv2.resize(np.asarray(img)/255, NEW_SIZE, interpolation = interp)
                    te += 1
                else:
                    test_masks[te,0:OG_SIZE[0],0:OG_SIZE[1]] = np.asarray(img)/255
                    te += 1
            else:
                if RESIZE:
                    test_imgs[te,0:NEW_SIZE[0],0:NEW_SIZE[1]] = cv2.resize(Scale(np.asarray(img)), NEW_SIZE, interpolation = interp)
                else:
                    test_imgs[te,0:OG_SIZE[0],0:OG_SIZE[1]] = Scale(np.asarray(img))
# Out:
# /content/drive/MyDrive/Images/data_validset/fracture_1x5.tif
# /content/drive/MyDrive/Images/data_validset/fracture_1x5_mask.tif
# /content/drive/MyDrive/Images/data_validset/fracture_2x4.tif
# /content/drive/MyDrive/Images/data_validset/fracture_2x4_mask.tif
# /content/drive/MyDrive/Images/data_validset/fracture_3x4.tif
# /content/drive/MyDrive/Images/data_validset/fracture_3x4_mask.tif
# /content/drive/MyDrive/Images/data_validset/fracture_3x6.tif
# /content/drive/MyDrive/Images/data_validset/fracture_3x6_mask.tif
# /content/drive/MyDrive/Images/data_validset/fracture_5x7.tif
# /content/drive/MyDrive/Images/data_validset/fracture_5x7_mask.tif
# /content/drive/MyDrive/Images/data_validset/fracture_7x3.tif
# /content/drive/MyDrive/Images/data_validset/fracture_7x3_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_1x6.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_1x6_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_2x3.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_2x3_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_2x5.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_2x5_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_2x6.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_2x6_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_3x3.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_3x3_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_3x5.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_3x5_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_3x8.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_3x8_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x3.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x3_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x4.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x4_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x5.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x5_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x6.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x6_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x7.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x7_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x8.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_4x8_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x2.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x2_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x3.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x3_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x5.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x5_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x6.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_5x6_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x1.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x1_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x2.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x2_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x3.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x3_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x4.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x4_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x5.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_6x5_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_7x1.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_7x1_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_7x2.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_7x2_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_8x1.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_8x1_mask.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_8x2.tif
# /content/drive/MyDrive/Images/data_trainset/fracture_8x2_mask.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask12x21.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask12x21_mask.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask22x38.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask22x38_mask.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask32x32.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask32x32_mask.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask35x25.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask35x25_mask.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask4x24.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask4x24_mask.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask9x10.tif
# /content/drive/MyDrive/Images/data_testset/MOA209_125m_mask9x10_mask.tif

# %%
#Only really needed if memory problems,
#Keep in code tho
#If DIV is set to 1 it will work how you guys need it
@njit
def ReshapeX(arr, div):
    out = np.zeros((int((div**2)*arr.shape[0]), int(arr.shape[1]/div), int(arr.shape[2]/div)))
    oc = 0
    for img in arr:
        for d1 in range(div):
            for d2 in range(div):
                out[oc,:,:] = img[d1*int(arr.shape[1]/div):(d1+1)*int(arr.shape[1]/div), d2*int(arr.shape[2]/div):(d2+1)*int(arr.shape[2]/div)]
                oc += 1
    return out

X_train = ReshapeX(train_imgs, DIV)
X_valid = ReshapeX(valid_imgs, DIV)
X_test = ReshapeX(test_imgs, DIV)


#Adds an extra dimension, neccesary for keras formatting
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],X_train.shape[2],1)
X_valid = X_valid.reshape(X_valid.shape[0],X_valid.shape[1],X_valid.shape[2],1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],X_test.shape[2],1)

#puts Y data into 1 hot encoded formatting for keras
@njit
def OHE(arr, div):
    out = np.zeros((int((div**2)*arr.shape[0]), int(arr.shape[1]/div), int(arr.shape[2]/div), 2, 1))
    
    oc = 0
    for img in arr:
        for d1 in range(div):
            for d2 in range(div):
                pc = 0
                ic = 0
                for i in range(d1*int(arr.shape[1]/div),(d1+1)*int(arr.shape[1]/div)):
                    jc = 0
                    for j in range(d2*int(arr.shape[2]/div),(d2+1)*int(arr.shape[2]/div)):
                        value = img[i,j]
                        if int(value) == 0:
                            out[oc,ic,jc,:] = np.array([[1], [0]]) #No fracture
                        if int(value) == 1:
                            out[oc,ic,jc,:] = np.array([[0], [1]]) #Fracture
                        pc += 1
                        jc += 1
                    ic += 1
                oc += 1
    return out

Y_train = OHE(train_masks,DIV)
Y_valid = OHE(valid_masks,DIV)
Y_test = OHE(test_masks,DIV)


#Adds weight to samples for loss funtion
#since there are so few fracture pixels compared to no fracture
#it helps to add additional weight in our loss function to the fracture class
#Right now fractures are weighted 3x as much as no fracture
#If you don't wanna use it, dont pass it through your fit funtion
@njit
def SampleWeight(arr):
    ws = np.ones((arr.shape[0],arr.shape[1],arr.shape[2]))
    for b, block in enumerate(arr):
        for i, ival in enumerate(block):
            for j, jval in enumerate(ival):
                if jval[0,0] == 0:
                    ws[b,i,j] = 2.5 #Change this number to set the fracture weight
    return ws

sample_weight_train = SampleWeight(Y_train)
sample_weight_valid = SampleWeight(Y_valid)

# %%
#Instantiate the model, compile the model, and train the model
#several parameters of this step will need customization depending of the model

#Take note of the input_shape... you will need that
model = segnet(input_shape = (int(NEW_SIZE[0]/DIV), int(NEW_SIZE[1]/DIV), 1), n_labels = 2, output_mode="softmax", num_filters=32)

loss = tf.keras.losses.BinaryCrossentropy()

#Learning rate was tuned for my specific model
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss=loss, optimizer=optimizer, metrics=['categorical_accuracy'], )

#Stop training when validation loss is at minimum and restore weights from that epoch
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

#Arbitrarily high epochs to ensure callback is found
history = model.fit(X_train, Y_train, validation_data=(X_valid, Y_valid, sample_weight_valid), epochs=10000, verbose=1, batch_size=2, sample_weight=sample_weight_train, callbacks=[callback])
# Out:
# Epoch 1/10000
# 13/13 [==============================] - 14s 175ms/step - loss: 0.7505 - categorical_accuracy: 0.0893 - val_loss: 0.6871 - val_categorical_accuracy: 0.8877
# Epoch 2/10000
# 13/13 [==============================] - 2s 128ms/step - loss: 0.7164 - categorical_accuracy: 0.0975 - val_loss: 0.6904 - val_categorical_accuracy: 0.8891
# Epoch 3/10000
# 13/13 [==============================] - 2s 127ms/step - loss: 0.6989 - categorical_accuracy: 0.4751 - val_loss: 0.6909 - val_categorical_accuracy: 0.8860
# Epoch 4/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6904 - categorical_accuracy: 0.8405 - val_loss: 0.6850 - val_categorical_accuracy: 0.8839
# Epoch 5/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6822 - categorical_accuracy: 0.8927 - val_loss: 0.6788 - val_categorical_accuracy: 0.9054
# Epoch 6/10000
# 13/13 [==============================] - 2s 128ms/step - loss: 0.6746 - categorical_accuracy: 0.9725 - val_loss: 0.6727 - val_categorical_accuracy: 0.9473
# Epoch 7/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.6675 - categorical_accuracy: 0.9796 - val_loss: 0.6666 - val_categorical_accuracy: 0.9641
# Epoch 8/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.6596 - categorical_accuracy: 0.9806 - val_loss: 0.6600 - val_categorical_accuracy: 0.9829
# Epoch 9/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.6536 - categorical_accuracy: 0.9861 - val_loss: 0.6533 - val_categorical_accuracy: 0.9912
# Epoch 10/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.6466 - categorical_accuracy: 0.9899 - val_loss: 0.6467 - val_categorical_accuracy: 0.9935
# Epoch 11/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6400 - categorical_accuracy: 0.9914 - val_loss: 0.6405 - val_categorical_accuracy: 0.9941
# Epoch 12/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6344 - categorical_accuracy: 0.9907 - val_loss: 0.6341 - val_categorical_accuracy: 0.9943
# Epoch 13/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.6321 - categorical_accuracy: 0.9878 - val_loss: 0.6245 - val_categorical_accuracy: 0.9895
# Epoch 14/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.6259 - categorical_accuracy: 0.9846 - val_loss: 0.6200 - val_categorical_accuracy: 0.9871
# Epoch 15/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6194 - categorical_accuracy: 0.9904 - val_loss: 0.6166 - val_categorical_accuracy: 0.9881
# Epoch 16/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6129 - categorical_accuracy: 0.9913 - val_loss: 0.6111 - val_categorical_accuracy: 0.9942
# Epoch 17/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.6067 - categorical_accuracy: 0.9923 - val_loss: 0.6057 - val_categorical_accuracy: 0.9943
# Epoch 18/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.6011 - categorical_accuracy: 0.9923 - val_loss: 0.6006 - val_categorical_accuracy: 0.9943
# Epoch 19/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.5957 - categorical_accuracy: 0.9920 - val_loss: 0.5955 - val_categorical_accuracy: 0.9944
# Epoch 20/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.5901 - categorical_accuracy: 0.9916 - val_loss: 0.5899 - val_categorical_accuracy: 0.9945
# Epoch 21/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.5848 - categorical_accuracy: 0.9914 - val_loss: 0.5845 - val_categorical_accuracy: 0.9945
# Epoch 22/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.5793 - categorical_accuracy: 0.9911 - val_loss: 0.5790 - val_categorical_accuracy: 0.9945
# Epoch 23/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.5743 - categorical_accuracy: 0.9914 - val_loss: 0.5732 - val_categorical_accuracy: 0.9946
# Epoch 24/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.5685 - categorical_accuracy: 0.9913 - val_loss: 0.5679 - val_categorical_accuracy: 0.9946
# Epoch 25/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.5644 - categorical_accuracy: 0.9893 - val_loss: 0.5624 - val_categorical_accuracy: 0.9943
# Epoch 26/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.5595 - categorical_accuracy: 0.9924 - val_loss: 0.5565 - val_categorical_accuracy: 0.9943
# Epoch 27/10000
# 13/13 [==============================] - 2s 128ms/step - loss: 0.5545 - categorical_accuracy: 0.9901 - val_loss: 0.5513 - val_categorical_accuracy: 0.9946
# Epoch 28/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.5494 - categorical_accuracy: 0.9917 - val_loss: 0.5460 - val_categorical_accuracy: 0.9946
# Epoch 29/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.5445 - categorical_accuracy: 0.9914 - val_loss: 0.5417 - val_categorical_accuracy: 0.9946
# Epoch 30/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.5391 - categorical_accuracy: 0.9908 - val_loss: 0.5378 - val_categorical_accuracy: 0.9940
# Epoch 31/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.5349 - categorical_accuracy: 0.9892 - val_loss: 0.5334 - val_categorical_accuracy: 0.9941
# Epoch 32/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.5298 - categorical_accuracy: 0.9911 - val_loss: 0.5296 - val_categorical_accuracy: 0.9935
# Epoch 33/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.5255 - categorical_accuracy: 0.9905 - val_loss: 0.5241 - val_categorical_accuracy: 0.9942
# Epoch 34/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.5203 - categorical_accuracy: 0.9910 - val_loss: 0.5210 - val_categorical_accuracy: 0.9915
# Epoch 35/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.5164 - categorical_accuracy: 0.9906 - val_loss: 0.5158 - val_categorical_accuracy: 0.9925
# Epoch 36/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.5112 - categorical_accuracy: 0.9905 - val_loss: 0.5090 - val_categorical_accuracy: 0.9946
# Epoch 37/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.5066 - categorical_accuracy: 0.9906 - val_loss: 0.5058 - val_categorical_accuracy: 0.9920
# Epoch 38/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.5024 - categorical_accuracy: 0.9898 - val_loss: 0.4999 - val_categorical_accuracy: 0.9946
# Epoch 39/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4990 - categorical_accuracy: 0.9913 - val_loss: 0.4949 - val_categorical_accuracy: 0.9945
# Epoch 40/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4940 - categorical_accuracy: 0.9912 - val_loss: 0.4911 - val_categorical_accuracy: 0.9946
# Epoch 41/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4901 - categorical_accuracy: 0.9923 - val_loss: 0.4882 - val_categorical_accuracy: 0.9946
# Epoch 42/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4858 - categorical_accuracy: 0.9910 - val_loss: 0.4842 - val_categorical_accuracy: 0.9944
# Epoch 43/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4813 - categorical_accuracy: 0.9915 - val_loss: 0.4800 - val_categorical_accuracy: 0.9944
# Epoch 44/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4776 - categorical_accuracy: 0.9910 - val_loss: 0.4763 - val_categorical_accuracy: 0.9940
# Epoch 45/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4741 - categorical_accuracy: 0.9921 - val_loss: 0.4728 - val_categorical_accuracy: 0.9931
# Epoch 46/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4693 - categorical_accuracy: 0.9909 - val_loss: 0.4682 - val_categorical_accuracy: 0.9918
# Epoch 47/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4667 - categorical_accuracy: 0.9934 - val_loss: 0.4622 - val_categorical_accuracy: 0.9944
# Epoch 48/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4620 - categorical_accuracy: 0.9926 - val_loss: 0.4635 - val_categorical_accuracy: 0.9904
# Epoch 49/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4573 - categorical_accuracy: 0.9902 - val_loss: 0.4587 - val_categorical_accuracy: 0.9924
# Epoch 50/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4532 - categorical_accuracy: 0.9908 - val_loss: 0.4525 - val_categorical_accuracy: 0.9939
# Epoch 51/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4492 - categorical_accuracy: 0.9921 - val_loss: 0.4488 - val_categorical_accuracy: 0.9944
# Epoch 52/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.4458 - categorical_accuracy: 0.9908 - val_loss: 0.4463 - val_categorical_accuracy: 0.9936
# Epoch 53/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4398 - categorical_accuracy: 0.9894 - val_loss: 0.4435 - val_categorical_accuracy: 0.9922
# Epoch 54/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4403 - categorical_accuracy: 0.9925 - val_loss: 0.4341 - val_categorical_accuracy: 0.9946
# Epoch 55/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.4361 - categorical_accuracy: 0.9932 - val_loss: 0.4311 - val_categorical_accuracy: 0.9944
# Epoch 56/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4305 - categorical_accuracy: 0.9918 - val_loss: 0.4344 - val_categorical_accuracy: 0.9902
# Epoch 57/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.4281 - categorical_accuracy: 0.9917 - val_loss: 0.4272 - val_categorical_accuracy: 0.9934
# Epoch 58/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4223 - categorical_accuracy: 0.9914 - val_loss: 0.4230 - val_categorical_accuracy: 0.9944
# Epoch 59/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4226 - categorical_accuracy: 0.9932 - val_loss: 0.4189 - val_categorical_accuracy: 0.9946
# Epoch 60/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4187 - categorical_accuracy: 0.9934 - val_loss: 0.4174 - val_categorical_accuracy: 0.9942
# Epoch 61/10000
# 13/13 [==============================] - 2s 133ms/step - loss: 0.4166 - categorical_accuracy: 0.9864 - val_loss: 0.4153 - val_categorical_accuracy: 0.9858
# Epoch 62/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4135 - categorical_accuracy: 0.9927 - val_loss: 0.4142 - val_categorical_accuracy: 0.9827
# Epoch 63/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4096 - categorical_accuracy: 0.9924 - val_loss: 0.4086 - val_categorical_accuracy: 0.9885
# Epoch 64/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.4064 - categorical_accuracy: 0.9919 - val_loss: 0.4090 - val_categorical_accuracy: 0.9864
# Epoch 65/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.4022 - categorical_accuracy: 0.9915 - val_loss: 0.4019 - val_categorical_accuracy: 0.9906
# Epoch 66/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3988 - categorical_accuracy: 0.9911 - val_loss: 0.3940 - val_categorical_accuracy: 0.9938
# Epoch 67/10000
# 13/13 [==============================] - 2s 128ms/step - loss: 0.3956 - categorical_accuracy: 0.9921 - val_loss: 0.3948 - val_categorical_accuracy: 0.9914
# Epoch 68/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3904 - categorical_accuracy: 0.9915 - val_loss: 0.3879 - val_categorical_accuracy: 0.9946
# Epoch 69/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3901 - categorical_accuracy: 0.9925 - val_loss: 0.3852 - val_categorical_accuracy: 0.9941
# Epoch 70/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3851 - categorical_accuracy: 0.9926 - val_loss: 0.3862 - val_categorical_accuracy: 0.9915
# Epoch 71/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3820 - categorical_accuracy: 0.9922 - val_loss: 0.3801 - val_categorical_accuracy: 0.9935
# Epoch 72/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3785 - categorical_accuracy: 0.9909 - val_loss: 0.3775 - val_categorical_accuracy: 0.9934
# Epoch 73/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3757 - categorical_accuracy: 0.9925 - val_loss: 0.3732 - val_categorical_accuracy: 0.9941
# Epoch 74/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3735 - categorical_accuracy: 0.9918 - val_loss: 0.3695 - val_categorical_accuracy: 0.9940
# Epoch 75/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3718 - categorical_accuracy: 0.9921 - val_loss: 0.3653 - val_categorical_accuracy: 0.9944
# Epoch 76/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3690 - categorical_accuracy: 0.9930 - val_loss: 0.3606 - val_categorical_accuracy: 0.9946
# Epoch 77/10000
# 13/13 [==============================] - 2s 128ms/step - loss: 0.3645 - categorical_accuracy: 0.9934 - val_loss: 0.3648 - val_categorical_accuracy: 0.9903
# Epoch 78/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3613 - categorical_accuracy: 0.9918 - val_loss: 0.3751 - val_categorical_accuracy: 0.9791
# Epoch 79/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3614 - categorical_accuracy: 0.9922 - val_loss: 0.3569 - val_categorical_accuracy: 0.9908
# Epoch 80/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3573 - categorical_accuracy: 0.9933 - val_loss: 0.3533 - val_categorical_accuracy: 0.9925
# Epoch 81/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3534 - categorical_accuracy: 0.9929 - val_loss: 0.3517 - val_categorical_accuracy: 0.9933
# Epoch 82/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3488 - categorical_accuracy: 0.9920 - val_loss: 0.3484 - val_categorical_accuracy: 0.9940
# Epoch 83/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3479 - categorical_accuracy: 0.9928 - val_loss: 0.3449 - val_categorical_accuracy: 0.9941
# Epoch 84/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3422 - categorical_accuracy: 0.9924 - val_loss: 0.3458 - val_categorical_accuracy: 0.9921
# Epoch 85/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3425 - categorical_accuracy: 0.9920 - val_loss: 0.3381 - val_categorical_accuracy: 0.9945
# Epoch 86/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3406 - categorical_accuracy: 0.9935 - val_loss: 0.3364 - val_categorical_accuracy: 0.9944
# Epoch 87/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3377 - categorical_accuracy: 0.9930 - val_loss: 0.3382 - val_categorical_accuracy: 0.9918
# Epoch 88/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3315 - categorical_accuracy: 0.9924 - val_loss: 0.3358 - val_categorical_accuracy: 0.9918
# Epoch 89/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3295 - categorical_accuracy: 0.9925 - val_loss: 0.3315 - val_categorical_accuracy: 0.9930
# Epoch 90/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3302 - categorical_accuracy: 0.9925 - val_loss: 0.3247 - val_categorical_accuracy: 0.9944
# Epoch 91/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3291 - categorical_accuracy: 0.9932 - val_loss: 0.3234 - val_categorical_accuracy: 0.9941
# Epoch 92/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3238 - categorical_accuracy: 0.9915 - val_loss: 0.3251 - val_categorical_accuracy: 0.9917
# Epoch 93/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3201 - categorical_accuracy: 0.9929 - val_loss: 0.3189 - val_categorical_accuracy: 0.9940
# Epoch 94/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3184 - categorical_accuracy: 0.9922 - val_loss: 0.3159 - val_categorical_accuracy: 0.9938
# Epoch 95/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3147 - categorical_accuracy: 0.9930 - val_loss: 0.3126 - val_categorical_accuracy: 0.9946
# Epoch 96/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.3134 - categorical_accuracy: 0.9929 - val_loss: 0.3130 - val_categorical_accuracy: 0.9938
# Epoch 97/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.3075 - categorical_accuracy: 0.9918 - val_loss: 0.3111 - val_categorical_accuracy: 0.9945
# Epoch 98/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3099 - categorical_accuracy: 0.9928 - val_loss: 0.3087 - val_categorical_accuracy: 0.9942
# Epoch 99/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3074 - categorical_accuracy: 0.9929 - val_loss: 0.3093 - val_categorical_accuracy: 0.9929
# Epoch 100/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.3056 - categorical_accuracy: 0.9927 - val_loss: 0.3036 - val_categorical_accuracy: 0.9946
# Epoch 101/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.3032 - categorical_accuracy: 0.9925 - val_loss: 0.3078 - val_categorical_accuracy: 0.9908
# Epoch 102/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.2997 - categorical_accuracy: 0.9929 - val_loss: 0.3169 - val_categorical_accuracy: 0.9833
# Epoch 103/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.2962 - categorical_accuracy: 0.9915 - val_loss: 0.3058 - val_categorical_accuracy: 0.9885
# Epoch 104/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2980 - categorical_accuracy: 0.9931 - val_loss: 0.3001 - val_categorical_accuracy: 0.9915
# Epoch 105/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.2910 - categorical_accuracy: 0.9924 - val_loss: 0.2926 - val_categorical_accuracy: 0.9943
# Epoch 106/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.2933 - categorical_accuracy: 0.9934 - val_loss: 0.2938 - val_categorical_accuracy: 0.9930
# Epoch 107/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.2909 - categorical_accuracy: 0.9924 - val_loss: 0.2885 - val_categorical_accuracy: 0.9940
# Epoch 108/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2869 - categorical_accuracy: 0.9932 - val_loss: 0.2876 - val_categorical_accuracy: 0.9940
# Epoch 109/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2820 - categorical_accuracy: 0.9921 - val_loss: 0.2851 - val_categorical_accuracy: 0.9944
# Epoch 110/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2835 - categorical_accuracy: 0.9932 - val_loss: 0.2836 - val_categorical_accuracy: 0.9941
# Epoch 111/10000
# 13/13 [==============================] - 2s 129ms/step - loss: 0.2816 - categorical_accuracy: 0.9929 - val_loss: 0.2871 - val_categorical_accuracy: 0.9909
# Epoch 112/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.2801 - categorical_accuracy: 0.9928 - val_loss: 0.2779 - val_categorical_accuracy: 0.9945
# Epoch 113/10000
# 13/13 [==============================] - 2s 128ms/step - loss: 0.2776 - categorical_accuracy: 0.9932 - val_loss: 0.2780 - val_categorical_accuracy: 0.9944
# Epoch 114/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2738 - categorical_accuracy: 0.9926 - val_loss: 0.2750 - val_categorical_accuracy: 0.9939
# Epoch 115/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2714 - categorical_accuracy: 0.9926 - val_loss: 0.2708 - val_categorical_accuracy: 0.9945
# Epoch 116/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.2690 - categorical_accuracy: 0.9929 - val_loss: 0.2689 - val_categorical_accuracy: 0.9946
# Epoch 117/10000
# 13/13 [==============================] - 2s 130ms/step - loss: 0.2667 - categorical_accuracy: 0.9932 - val_loss: 0.2687 - val_categorical_accuracy: 0.9933
# Epoch 118/10000
# 13/13 [==============================] - 2s 131ms/step - loss: 0.2668 - categorical_accuracy: 0.9924 - val_loss: 0.2639 - val_categorical_accuracy: 0.9946
# Epoch 119/10000
# 13/13 [==============================] - 2s 133ms/step - loss: 0.2692 - categorical_accuracy: 0.9935 - val_loss: 0.2625 - val_categorical_accuracy: 0.9944
# Epoch 120/10000
# 13/13 [==============================] - 2s 133ms/step - loss: 0.2613 - categorical_accuracy: 0.9932 - val_loss: 0.2611 - val_categorical_accuracy: 0.9945
# Epoch 121/10000
# 13/13 [==============================] - 2s 132ms/step - loss: 0.2595 - categorical_accuracy: 0.9932 - val_loss: 0.2584 - val_categorical_accuracy: 0.9946
# Epoch 122/10000
# 13/13 [==============================] - 2s 133ms/step - loss: 0.2613 - categorical_accuracy: 0.9934 - val_loss: 0.2576 - val_categorical_accuracy: 0.9942
# Epoch 123/10000
#  8/13 [=================>............] - ETA: 0s - loss: 0.2672 - categorical_accuracy: 0.9907
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-48-a42f76106724> in <module>()
#      15
#      16 #Arbitrarily high epochs to ensure callback is found
# ---> 17 history = model.fit(X_train, Y_train, validation_data=(X_valid, Y_valid, sample_weight_valid), epochs=10000, verbose=1, batch_size=2, sample_weight=sample_weight_train, callbacks=[callback])
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3130     return graph_function._call_flat(
# -> 3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#    3133   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958       # No tape is watching; skip to running the function.
#    1959       return self._build_call_outputs(self._inference_function.call(
# -> 1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#    1962         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     601               inputs=args,
#     602               attrs=attrs,
# --> 603               ctx=ctx)
#     604         else:
#     605           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57     ctx.ensure_initialized()
#      58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#      61     if name is not None:
#
# KeyboardInterrupt:

# %%
#Undo reshape I used for memory and take argmax of results (Just takes argmax if DIV = 1)
#arg_arg true or false if you want argmax or not, respectively
def preds2imgs(arr, div, arg_arg):
    if arg_arg:
        temp = np.argmax(arr, axis=3)
        out = np.zeros((int((arr.shape[0])/(div**2)),int((arr.shape[1]*div)),int(arr.shape[1]*div)))
    else:
        temp = arr
        out = np.zeros((int((arr.shape[0])/(div**2)),int((arr.shape[1]*div)),int(arr.shape[1]*div),2))
        
    tc = 0
    for img in range(int((arr.shape[0])/(div**2))):
        for d1 in range(div):
            for d2 in range(div):
                if arg_arg:
                    out[img, d1*int(temp.shape[1]):(d1+1)*int(temp.shape[1]), d2*int(temp.shape[1]):(d2+1)*int(temp.shape[1])] = temp[tc]
                    tc += 1
                else:
                    out[img, d1*int(temp.shape[1]):(d1+1)*int(temp.shape[1]), d2*int(temp.shape[1]):(d2+1)*int(temp.shape[1]),:] = temp[tc]
                    tc += 1
    return out


#Show loss and accuracy of all datasets from epoch of restored weights
acc_train = model.evaluate(X_train, Y_train, verbose=0, batch_size=1)
print(" Train loss: ", acc_train[0], " Train accuracy: ", acc_train[1])
acc_valid = model.evaluate(X_valid, Y_valid, verbose=0, batch_size=1)
print(" Valid loss: ", acc_valid[0], " Valid accuracy: ", acc_valid[1])
acc_test = model.evaluate(X_test, Y_test, verbose=0, batch_size=1)
print(" Test loss: ", acc_test[0], " Test accuracy: ", acc_test[1])

#predict your results
valid_results = model.predict(X_valid, batch_size=1)
test_results = model.predict(X_test, batch_size=1)

valid_argmax_pred = preds2imgs(valid_results, DIV, True)
valid_argmax_true = preds2imgs(np.squeeze(Y_valid, axis = 4), DIV, True)

test_argmax_pred = preds2imgs(test_results, DIV, True)
test_argmax_true = preds2imgs(np.squeeze(Y_test, axis = 4), DIV, True)

# #Plot accuracies from training
# plt.plot(history.history['categorical_accuracy'])
# plt.plot(history.history['val_categorical_accuracy'])
# plt.title('model accuracy')
# plt.ylabel('accuracy')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()

# #Plot losses from training
# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
# plt.title('model loss')
# plt.ylabel('loss')
# plt.xlabel('epoch')
# plt.legend(['train', 'val'], loc='upper left')
# plt.show()


#Resizes or removes padding from argmax results depending on which you used.
def ToOGSize(arr, num_images, RESIZE, OG_SIZE, interp):
    OG = np.zeros((num_images,OG_SIZE[0],OG_SIZE[1]))
    for i in range(num_images):
        if RESIZE:
            OG[i,:,:] = cv2.resize(arr[i], OG_SIZE, interpolation=interp)
        else:
            OG[i,:,:] = arr[i,0:OG_SIZE[0],0:OG_SIZE[1]]
    return OG

valid_argmax_pred_OG = ToOGSize(valid_argmax_pred,
                                6, RESIZE,
                                OG_SIZE, interp)
valid_argmax_true_OG = ToOGSize(valid_argmax_true,
                                6, RESIZE,
                                OG_SIZE, interp)

test_argmax_pred_OG = ToOGSize(test_argmax_pred,
                               6, RESIZE,
                               OG_SIZE, interp)

test_argmax_true_OG = ToOGSize(test_argmax_true,
                               6, RESIZE,
                               OG_SIZE, interp)
# Out:
#  Train loss:  0.2460753619670868  Train accuracy:  0.993996262550354
#  Valid loss:  0.24483565986156464  Valid accuracy:  0.9947007298469543
#  Test loss:  0.25337889790534973  Test accuracy:  0.9877064824104309

# %%
#Plot argmax results for validation data and GT
for i, pred in enumerate(valid_argmax_pred_OG):
    plt.imshow(pred,cmap='binary')
    plt.title("ArgMax Pred Validation "+ str(i))
    plt.show()
    plt.imshow(valid_argmax_true_OG[i], cmap='binary')
    plt.title("GT Validation "+ str(i))
    plt.show()

# %%
#Formats the data as neccesary to use sklearn roc_curve function
def ToROC(arr, arr_pred):
    out = np.zeros(int(arr.shape[0]*arr.shape[1]*arr.shape[2]))
    out_pred = np.zeros(int(arr.shape[0]*arr.shape[1]*arr.shape[2]))
    c = 0
    for b, block in enumerate(arr):
        for i, ival in enumerate(block):
            for j, jval in enumerate(ival):
                if jval[1] == 1:
                    out[c] = 1
                
                out_pred[c] = arr_pred[b,i,j,1]
                c += 1
    return out, out_pred

temp_Y_valid_OG = Y_valid.reshape(6,NEW_SIZE[0],NEW_SIZE[0],2,1)
Y_valid_OG = np.zeros((6,OG_SIZE[0],OG_SIZE[0],2,1))

temp_valid_results_OG = valid_results.reshape(6,NEW_SIZE[0],NEW_SIZE[0],2)
valid_results_OG = np.zeros((6,OG_SIZE[0],OG_SIZE[0],2,1))

if RESIZE:
    for i in range(6):
        temp_OG_0 = cv2.resize(temp_Y_valid_OG[i,:,:,0,0], OG_SIZE, interpolation=interp)
        temp_OG_1 = cv2.resize(temp_Y_valid_OG[i,:,:,1,0], OG_SIZE, interpolation=interp)
        Y_valid_OG[i,:,:,0,0] = temp_OG_0
        Y_valid_OG[i,:,:,1,0] = temp_OG_1
        
        temp_OG_0 = cv2.resize(temp_valid_results_OG[i,:,:,0], OG_SIZE, interpolation=interp)
        temp_OG_1 = cv2.resize(temp_valid_results_OG[i,:,:,1], OG_SIZE, interpolation=interp)
        
        valid_results_OG[i,:,:,0] = np.expand_dims(temp_OG_0, axis = 2)
        valid_results_OG[i,:,:,1] = np.expand_dims(temp_OG_1, axis = 2)
else:
    Y_valid_OG = temp_Y_valid_OG[:,0:OG_SIZE[0],0:OG_SIZE[1],:,:]
    valid_results_OG = temp_valid_results_OG[:,0:OG_SIZE[0],0:OG_SIZE[1],:]

#Generates the ROC curve and solves the AUC
valid_roc_true, valid_roc_pred = ToROC(np.squeeze(Y_valid_OG, axis=4), valid_results_OG)
fpr, tpr, thresholds = roc_curve(valid_roc_true, valid_roc_pred, pos_label=1)
roc_auc = auc(fpr, tpr)

#Plot ROC curve and print AUC score
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label = 'ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color = 'navy', lw=lw, linestyle = '--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Validation Receiver Operating Characteristic')
plt.legend(loc = 'lower right')
plt.show()
print('AUC = ',roc_auc)


#Determine the fracture threshold best suitable for maximizing f1-score based on validation data
f1 = []
spacing = 0.05
thr = np.arange(0,1,spacing)
for i in thr:
    f1.append(f1_score(valid_roc_true, (valid_roc_pred > i)))

#saves value of best threshold
threshold = np.argmax(f1)*spacing

#Plots the f1-score as a function of threshold values
plt.figure()
plt.plot(thr, f1)
plt.xlim([0,1])
plt.xlabel('threshold')
plt.ylabel('f1-score')
plt.show()
# Out:
# AUC =  0.8429251818699941

# %%
#Applies threshold found previously to test results

def ApplyThreshold(arr, thr):
    out = np.zeros((arr.shape[0],arr.shape[1],arr.shape[2]))
    for b, block in enumerate(arr):
        for i, ival in enumerate(block):
            for j, jval in enumerate(ival):
                if jval[1] >= thr:
                    out[b,i,j] = 1
    return out

test_pred_thr = ApplyThreshold(preds2imgs(test_results, DIV, False), threshold)

#Reshapes raw test probability results as neccesary for plotting.
temp_Y_test_OG = Y_test.reshape(6,NEW_SIZE[0],NEW_SIZE[0],2,1)
Y_test_OG = np.zeros((6,OG_SIZE[0],OG_SIZE[0],2,1))

temp_test_results_OG = test_results.reshape(6,NEW_SIZE[0],NEW_SIZE[0],2)
test_results_OG = np.zeros((6,OG_SIZE[0],OG_SIZE[0],2,1))

if RESIZE:
    for i in range(6):
        temp_OG_0 = cv2.resize(temp_Y_test_OG[i,:,:,0,0], OG_SIZE, interpolation=interp)
        temp_OG_1 = cv2.resize(temp_Y_test_OG[i,:,:,1,0], OG_SIZE, interpolation=interp)
        Y_test_OG[i,:,:,0,0] = temp_OG_0
        Y_test_OG[i,:,:,1,0] = temp_OG_1
        
        temp_OG_0 = cv2.resize(temp_test_results_OG[i,:,:,0], OG_SIZE, interpolation=interp)
        temp_OG_1 = cv2.resize(temp_test_results_OG[i,:,:,1], OG_SIZE, interpolation=interp)
        
        test_results_OG[i,:,:,0] = np.expand_dims(temp_OG_0, axis = 2)
        test_results_OG[i,:,:,1] = np.expand_dims(temp_OG_1, axis = 2)
else:
    Y_test_OG = temp_Y_test_OG[:,0:OG_SIZE[0],0:OG_SIZE[1],:,:]
    test_results_OG = temp_test_results_OG[:,0:OG_SIZE[0],0:OG_SIZE[1],:]
        
#Plot the raw output of fractures, the ArgMax results, the Threshold applied results, and the Ground truths
for i in range(6):
#     plt.imshow(test_results_OG[i,:,:,1],cmap='binary') #Show if you use softmax activation
#     plt.title("Pred Fracture Value Test "+ str(i))
#     plt.show()
    plt.imshow(test_argmax_pred_OG[i],cmap='binary')
    plt.title("ArgMax Test "+ str(i))
    plt.show()
    plt.imshow(test_pred_thr[i,0:OG_SIZE[0],0:OG_SIZE[1]],cmap='binary')
    plt.title("Threshold Test "+ str(i))
    plt.show()
    plt.imshow(test_argmax_true_OG[i], cmap='binary')
    plt.title("GT Test "+ str(i))
    plt.show()


#Solve the ROC curve and AUC for test data
roc_true_Y, roc_pred_Y = ToROC(np.squeeze(Y_test_OG, axis=4), test_results_OG)
# fpr, tpr, thresholds = roc_curve(roc_true_Y, (roc_pred_Y > threshold), pos_label=1)
# roc_auc = auc(fpr, tpr)

# #Plot the ROC curve, print AUC, and print F1-score score for test data
# plt.figure()
# lw = 2
# plt.plot(fpr, tpr, color='darkorange', lw=lw, label = 'ROC curve (area = %0.4f)' % roc_auc)
# plt.plot([0, 1], [0, 1], color = 'navy', lw=lw, linestyle = '--')
# plt.xlim([0,1])
# plt.ylim([0,1])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Test Receiver Operating Characteristic')
# plt.legend(loc = 'lower right')
# plt.show()
# print('Threshold Test AUC = ',roc_auc)
print('Threshold Test F1-score = ', f1_score(roc_true_Y, (roc_pred_Y > threshold)))


# fpr, tpr, thresholds = roc_curve(test_argmax_true_OG.flatten(), test_argmax_pred_OG.flatten(), pos_label=1)
# roc_auc = auc(fpr, tpr)
# plt.figure()
# lw = 2
# plt.plot(fpr, tpr, color='darkorange', lw=lw, label = 'ROC curve (area = %0.4f)' % roc_auc)
# plt.plot([0, 1], [0, 1], color = 'navy', lw=lw, linestyle = '--')
# plt.xlim([0,1])
# plt.ylim([0,1])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Test Receiver Operating Characteristic')
# plt.legend(loc = 'lower right')
# plt.show()
# print('ArgMax Test AUC = ',roc_auc)
# print('ArgMax Test F1-score = ', f1_score(test_argmax_true_OG.flatten(), test_argmax_pred_OG.flatten()))


fpr, tpr, thresholds = roc_curve(Y_test_OG[:,:,:,1].flatten(), test_results_OG[:,:,:,1].flatten(), pos_label=1)
roc_auc = auc(fpr, tpr)
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange', lw=lw, label = 'ROC curve (area = %0.4f)' % roc_auc)
plt.plot([0, 1], [0, 1], color = 'navy', lw=lw, linestyle = '--')
plt.xlim([0,1])
plt.ylim([0,1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test Receiver Operating Characteristic')
plt.legend(loc = 'lower right')
plt.show()
print('Raw Preds Test AUC = ',roc_auc)
# Out:
# Threshold Test F1-score =  0.4322324085104424
# Raw Preds Test AUC =  0.838856329894521
